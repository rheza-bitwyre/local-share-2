# %% [markdown]
# ## Info
# * Data = `bloomberg_usd_idr_2012_2024_processed.csv`

# %%
import pandas as pd
import numpy as np
import datetime
import time

import torch
from torch import nn

import matplotlib.pyplot as plt

# %%
# Read data
df = pd.read_csv('bloomberg_usd_idr_2012_2024_processed.csv')

df
# Out:
#             date     open     high      low    close  gap_day  next_close  \
# 0     2012-01-02   9150.0   9200.0   9067.0   9080.0        1      9135.0
# 1     2012-01-03   9090.0   9185.0   9090.0   9135.0        1      9137.0
# 2     2012-01-04   9160.0   9185.0   9137.0   9137.0        1      9193.0
# 3     2012-01-05   9175.0   9203.0   9112.0   9193.0        1      9095.0
# 4     2012-01-06   9178.0   9213.0   9095.0   9095.0        3      9150.0
# ...          ...      ...      ...      ...      ...      ...         ...
# 3129  2024-10-21  15463.0  15498.0  15431.0  15495.0        1     15560.0
# 3130  2024-10-22  15534.0  15572.0  15534.0  15560.0        1     15620.0
# 3131  2024-10-23  15590.0  15633.0  15590.0  15620.0        1     15584.0
# 3132  2024-10-24  15640.0  15644.0  15580.0  15584.0        1     15640.0
# 3133  2024-10-25  15622.0  15643.0  15603.0  15640.0        3     15725.0
#
#       open_change  high_change  low_change  close_change    ma_close_5  \
# 0            50.0         -8.0         4.0          13.0   9074.000000
# 1           -60.0        -15.0        23.0          55.0   9094.000000
# 2            70.0          0.0        47.0           2.0   9117.333333
# 3            15.0         18.0       -25.0          56.0   9136.250000
# 4             3.0         10.0       -17.0         -98.0   9128.000000
# ...           ...          ...         ...           ...           ...
# 3129        -60.0        -25.0       -16.0          30.0  15485.000000
# 3130         71.0         74.0       103.0          65.0  15506.666667
# 3131         56.0         61.0        56.0          60.0  15558.333333
# 3132         50.0         11.0       -10.0         -36.0  15564.750000
# 3133        -18.0         -1.0        23.0          56.0  15579.800000
#
#        ma_close_10  prev_open  prev_high  prev_low  prev_close  daily_range  \
# 0      9070.833333     9100.0     9208.0    9063.0      9067.0        133.0
# 1      9080.000000     9150.0     9200.0    9067.0      9080.0         95.0
# 2      9087.125000     9090.0     9185.0    9090.0      9135.0         48.0
# 3      9104.375000     9160.0     9185.0    9137.0      9137.0         91.0
# 4      9106.875000     9175.0     9203.0    9112.0      9193.0        118.0
# ...            ...        ...        ...       ...         ...          ...
# 3129  15518.000000    15523.0    15523.0   15447.0     15465.0         67.0
# 3130  15524.000000    15463.0    15498.0   15431.0     15495.0         38.0
# 3131  15536.000000    15534.0    15572.0   15534.0     15560.0         43.0
# 3132  15539.000000    15590.0    15633.0   15590.0     15620.0         64.0
# 3133  15546.500000    15640.0    15644.0   15580.0     15584.0         40.0
#
#       gap_change  close_ma5_ratio  close_ma10_ratio
# 0           83.0         1.000661          1.001011
# 1           10.0         1.004508          1.006057
# 2           25.0         1.002157          1.005489
# 3           38.0         1.006212          1.009734
# 4          -15.0         0.996385          0.998696
# ...          ...              ...               ...
# 3129        -2.0         1.000646          0.998518
# 3130        39.0         1.003439          1.002319
# 3131        30.0         1.003964          1.005407
# 3132        20.0         1.001237          1.002896
# 3133        38.0         1.003864          1.006014
#
# [3134 rows x 21 columns]

# %%
pd.set_option('display.max_rows', 20)

# %%
pd.set_option('display.max_columns', 25)
