# %%
import pandas as pd
import numpy as np
import datetime
import time

# %%
# Read data
usd_idr_df = pd.read_csv('bloomberg_usd_idr_2012_2024_processed.csv')

usd_idr_df
# Out:
#             date     open     high      low    close  gap_day  next_close  \
# 0     2012-01-02   9150.0   9200.0   9067.0   9080.0        1      9135.0
# 1     2012-01-03   9090.0   9185.0   9090.0   9135.0        1      9137.0
# 2     2012-01-04   9160.0   9185.0   9137.0   9137.0        1      9193.0
# 3     2012-01-05   9175.0   9203.0   9112.0   9193.0        1      9095.0
# 4     2012-01-06   9178.0   9213.0   9095.0   9095.0        3      9150.0
# ...          ...      ...      ...      ...      ...      ...         ...
# 3129  2024-10-21  15463.0  15498.0  15431.0  15495.0        1     15560.0
# 3130  2024-10-22  15534.0  15572.0  15534.0  15560.0        1     15620.0
# 3131  2024-10-23  15590.0  15633.0  15590.0  15620.0        1     15584.0
# 3132  2024-10-24  15640.0  15644.0  15580.0  15584.0        1     15640.0
# 3133  2024-10-25  15622.0  15643.0  15603.0  15640.0        3     15725.0
#
#       open_change  high_change  low_change  ...    ma_close_5   ma_close_10  \
# ...

# %%
# Read data
usd_jpy_df = pd.read_csv('bloomberg_usd_jpy_2012_2024_processed.csv')

usd_jpy_df
# Out:
#             date    open    high     low   close  gap_day  next_close  \
# 0     2012-01-02   76.84   77.17   76.33   76.90        1       76.74
# 1     2012-01-03   76.90   76.97   76.63   76.74        1       76.72
# 2     2012-01-04   76.74   76.83   76.61   76.72        1       77.12
# 3     2012-01-05   76.72   77.25   76.66   77.12        1       76.97
# 4     2012-01-06   77.12   77.34   76.96   76.97        3       76.86
# ...          ...     ...     ...     ...     ...      ...         ...
# 3340  2024-10-21  149.56  150.89  149.09  150.84        1      151.08
# 3341  2024-10-22  150.84  151.20  150.50  151.08        1      152.76
# 3342  2024-10-23  151.08  153.19  151.03  152.76        1      151.83
# 3343  2024-10-24  152.76  152.83  151.55  151.83        1      152.31
# 3344  2024-10-25  151.83  152.38  151.46  152.31        3      153.29
#
#       open_change  high_change  low_change  ...  ma_close_5  ma_close_10  \
# ...
